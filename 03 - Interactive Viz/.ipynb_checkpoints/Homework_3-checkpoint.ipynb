# %% [markdown]
# # Homework 3 - Data vizualisation

# %% [markdown]
# First of all, necessary libraries are imported.

# %%
# %matplotlib inline
import os
import pandas as pd
import json
import folium
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.axes_style("darkgrid")
sns.set_palette("Set2")

# %% [markdown]
# # Task 1 : European unemployment rates
#
# Go to the eurostat website and try to find a dataset that includes the european unemployment rates at a recent date.
#
# Use this data to build a Choropleth map which shows the unemployment rate in Europe at a country level. Think about the colors you use, how you decided to split the intervals into data classes or which interactions you could add in order to make the visualization intuitive and expressive. Compare Switzerland's unemployment rate to that of the rest of Europe.

# %% [markdown]
# # Solution

# %% [markdown]
# ### Reasoning
#
#
# Our understanding of the recent date is previous year - 2016, as it is long enough time interval to get some real statistics about the unemployment. Other options that we considered were one month and half a year, but we think using this approach the results would be influenced by mountly migrations. For example more people are traveling during the winter and summer months as these are the holiday seasons, and are less likely to search for a job during these months.
#
#
# ### Load dataset
# To begin, we download a dataset on the [Eurostat](http://ec.europa.eu/eurostat/data/database) website by using the search bar and looking for the term *Unemployment*. We have chosen the dataset called "Total unemployment rate" (*tsdec450*) that contains unemployment rates per year, for most of the european countries.

# %%
total_unemployment_file_path = 'data/tsdec450.tsv'

# load the data
def load_data(file_name):
    df = pd.DataFrame()
    df = df.append( pd.read_csv(file_name, sep="\t" , header=0))
    # clean the column names
    df.columns = [i.split(" ")[0] for i in df.columns]
    df.columns = [i.split("\\")[0] for i in df.columns]
    new_col = df["age,unit,sex,geo"].str.split(",")
    # from one column with all data create two separate columns that are important to us
    df["State"] = [pi[3] for pi in new_col]
    df["Unit"] = [pi[1] for pi in new_col]
    
    return df

df = load_data(total_unemployment_file_path)
df.head()
# Out:
#     age,unit,sex,geo  1990  1991  1992  1993  1994  1995  1996  1997  1998  \
# 0  TOTAL,PC_ACT,T,AT    :     :     :     :   4.3   4.2   4.7   4.7   4.7
# 1  TOTAL,PC_ACT,T,BE  6.6   6.4   7.1   8.6   9.8   9.7   9.5   9.2   9.3
# 2  TOTAL,PC_ACT,T,BG    :     :     :     :     :     :     :     :     :
# 3  TOTAL,PC_ACT,T,CY    :     :     :     :     :     :     :     :     :
# 4  TOTAL,PC_ACT,T,CZ    :     :     :   4.3   4.3   4.0   3.9   4.8   6.5
#
#     ...    2009    2010   2011  2012  2013  2014  2015  2016 State    Unit
# 0   ...    5.3     4.8    4.6    4.9   5.4   5.6   5.7   6.0    AT  PC_ACT
# 1   ...    7.9     8.3    7.2    7.6   8.4   8.5   8.5   7.8    BE  PC_ACT
# 2   ...    6.8   10.3 i  11.3   12.3  13.0  11.4   9.2   7.6    BG  PC_ACT
# 3   ...    5.4     6.3    7.9   11.9  15.9  16.1  15.0  13.0    CY  PC_ACT
# 4   ...    6.7     7.3    6.7    7.0   7.0   6.1   5.1   4.0    CZ  PC_ACT
#
# [5 rows x 30 columns]

# %% [markdown]
# We found some mismatching in json geo-coordinate files, and country codes for two countries. Because of this we replace this codes in the dataframe in order to be consistent. Measurement unit's code for the metric that we want to present is PC_ACT, so we filter by this value.

# %%
#Pre-processing : keep only useful data
df['2016'] = df['2016'].astype(float)
df = df.query('Unit == \'PC_ACT\'')

# Put the same country code in the dataset and in json geo-coordinate files
df = df.replace('UK', 'GB')
df = df.replace('EL', 'GR')

# %%
df = df[['State', '2016']]
df.head()
# Out:
#   State  2016
# 0    AT   6.0
# 1    BE   7.8
# 2    BG   7.6
# 3    CY  13.0
# 4    CZ   4.0

# %% [markdown]
# ### Define classification function
# According to [GISGeography.com](http://gisgeography.com/choropleth-maps-data-classification/), we learn that selecting a data classification method is very important. It impacts very much our understanding of the data and thus it is important to find the right classification. We decided to code and test two of them:
# - **Equal Interval Data Classification** as *equal* : It divides the classes into equal groups of same interval length.
# - **Quantile classification** as *quantile*: It arranges the classes to have the same quantity inside.

# %%
# define functions for classifying the unemployment
def define_threshold(df, column_name, classification='equal', classes=4):
    # in case of 'equal' classification divide the groups into the intervals
    # of the same length
    if classification == 'equal':
        min_val = df[column_name].min()
        max_val = df[column_name].max()
        bins = []
        bins.append(min_val - 0.001)
        for i in np.arange(1, classes):
            bins.append(((max_val - min_val)* i/classes) + min_val)
        bins.append(max_val + 0.001)
        return bins
    
    # in case of 'quantile' classification divide the classes 
    # in such way that they have the same quantity inside
    if classification == 'quantile':
        out, bins = pd.qcut(df[column_name], classes, retbins=True)
        bins += 0.001
        return bins.tolist()

# %% [markdown]
# ### Plot european map
#
#
# We are plotting the map of percentage of unemployed people in european countries according to statistics for year 2016. This dataset does not provide us the data for each european country, so we had to think how to present this in understandable manner on the map. We choose to leave these countries colored the same way as the rest of the world, for which we do not show any statistics. This way intuitively should be clear that the data for these countries is missing.

# %%
geojson_path = 'topojson/europe.topojson.json'
topojson_path = json.load(open(geojson_path))

# Countries that were missing in the dataset are in the same color
# as the rest of the world for which we do not show any data
topojson_path['objects']['europe']['geometries'] = [
    feature for feature 
    in topojson_path['objects']['europe']['geometries'] 
    if (feature['id'] in df['State'].values) ]

# %% [markdown]
# #### Quantile approach

# %%
# Draw the map with our threshold classification function
# We use quantile approach here
eu_map = folium.Map([52.3, 9.7], tiles='cartodbpositron', zoom_start=3.6)
eu_map.choropleth(geo_data=topojson_path , data=df, topojson='objects.europe',
             columns=['State', '2016'],
             key_on='feature.id',
             fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.2,
             threshold_scale=define_threshold(df, '2016', classification='quantile',classes=4),
             legend_name='Percentage of unemployment (%)')

eu_map.save('maps/unemployment_europe_quantile_classfication.html')
eu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Link to the map preview
#
# Map can be found [here](http://ada.arassinoux.com/unemployment_europe_quantile_classfication.html)

# %% [markdown]
# #### Equal interval approach

# %%
# Draw the map with our threshold classification function
# We use equal interval approach here
eu_map = folium.Map([52.3, 9.7], tiles='cartodbpositron', zoom_start=3.6)
eu_map.choropleth(geo_data=topojson_path , data=df, topojson='objects.europe',
             columns=['State', '2016'],
             key_on='feature.id',
             fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.2,
             threshold_scale=define_threshold(df,'2016',classification='equal',classes=4),
             legend_name='Percentage of unemployment (%)')

eu_map.save('maps/unemployment_europe_equal_classification.html')
eu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Link to the map preview
#
# Map can be found [here](http://ada.arassinoux.com/unemployment_europe_equal_classification.html)

# %% [markdown]
# ### Observations
# Compare two classifications and select the best one for this problem : i think it is equal interval

# %% [markdown]
# # Task 2 : Swiss unemployment rates
#
# Go to the amstat website to find a dataset that includes the unemployment rates in Switzerland at a recent date.
#
# HINT Go to the details tab to find the raw data you need. If you do not speak French, German or Italian, think of using free translation services to navigate your way through.
# Use this data to build another Choropleth map, this time showing the unemployment rate at the level of swiss cantons. Again, try to make the map as expressive as possible, and comment on the trends you observe.
#
# The Swiss Confederation defines the rates you have just plotted as the number of people looking for a job divided by the size of the active population (scaled by 100). This is surely a valid choice, but as we discussed one could argue for a different categorization.
#
# Copy the map you have just created, but this time don't count in your statistics people who already have a job and are looking for a new one. How do your observations change ? You can repeat this with different choices of categories to see how selecting different metrics can lead to different interpretations of the same data.

# %% [markdown]
# # Solution
#
#
# We should apply the same methodology to display the unemployment rates in Switzerland. We start by loading the dataset from Amstat website. Using the same reasoning about this problem, we also decided to use the data for year 2016.

# %% [markdown]
# ## Assumptions
#
#
# In order to have the swiss cantons codes to fill our topojson file, we created a json file containing all cantons codes according to canton name. This dataframe will be used during the Tasks 2 and 3.

# %%
#TOPOJSON FILE
switzerland_path = './topojson/ch-cantons.topojson.json'
switzerland_topojson = json.load(open(switzerland_path))

# OUR CANTON CODES FILE
switzerland_cantoncodes_path = 'data/swiss_cantons.json'
cantons = pd.read_json(switzerland_cantoncodes_path, encoding='utf-8')

# %% [markdown]
# ## 2.1 - Unemployment rates
# First, we decided to plot on the map the unemployement rate.

# %% [markdown]
# ### Load dataset

# %%
# Load data to pandas dataframe
swiss_unemployed_filtered_path = 'data/unemployment.csv'
switzerland_unemployed_df = pd.read_csv(open(swiss_unemployed_filtered_path, 
                                             encoding='utf-16'),
                                             header=[1,2], 
                                             thousands='\'')

# choose columns of interest
switzerland_unemployed_df = switzerland_unemployed_df[['Canton','Total']]
# translate the columns that are initialy in french into english
cols= ['canton', 'unemployment_rate', 'unemployed_jobseekers', 'all_jobseekers', 'employed_jobseekers']
switzerland_unemployed_df.columns = cols
# drop the last row that is showing the total sum for all of cantons cumulatively
switzerland_unemployed_df.drop(switzerland_unemployed_df.index[len(switzerland_unemployed_df)-1], inplace=True)

#cantons
cantons.drop(cantons.index[len(cantons)-1], inplace=True)
cantons.columns = ['code', 'canton']

# information about canton codes is important, so merge these two dataframes into one 
# now we have all important information in switzerland_df 
switzerland_df = pd.merge(cantons,switzerland_unemployed_df, on=['canton'])
switzerland_df.head()
# Out:
#   code   canton  unemployment_rate  unemployed_jobseekers  all_jobseekers  \
# 0   ZH   Zurich                3.7                 361007          441431
# 1   BE    Berne                2.7                 183398          241011
# 2   LU  Lucerne                2.1                  55221           89599
# 3   UR      Uri                1.0                   2418            4361
# 4   SZ   Schwyz                1.8                  18446           27475
#
#    employed_jobseekers
# 0                80424
# 1                57613
# 2                34378
# 3                 1943
# 4                 9029

# %% [markdown]
# ### Plot Switzerland map

# %%
switzerland_map = folium.Map([46.8001, 8.1958], tiles='cartodbpositron', zoom_start=8)

switzerland_map.choropleth(geo_data=switzerland_topojson,
                            data=switzerland_df, topojson='objects.cantons',
                            columns=['code', 'unemployment_rate'],
                            key_on='feature.id',
                            fill_color='YlOrRd', fill_opacity=0.6, line_opacity=0.2,
                            legend_name='Unemployment rate (%)')


switzerland_map.save('maps/unemployment_switzerland.html')
switzerland_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Link to the map preview
#
# Map can be found [here](http://ada.arassinoux.com/unemployment_switzerland.html)

# %% [markdown]
# ## Observations
#
# Regarding the unemployment rate in Switzerland, we notice next trends:
#  - Geneva and Jura cantons have the highest unemployement rate.
#  - Cantons like Uri and Schwytz have the lowest unemployement rate.
#  - Going from eastern to western Switzerland, we notice that the unemployment rate is increasing (starting from 1% in the east to 5.8% to the west).
#  - The canton Zurich is isolated from it's neighbours. Comparing the percentage of unemployed people, it is similar to western cantons.

# %% [markdown]
# ## Back to task 1 - compare Switzerland with another countries

# %%
row = pd.DataFrame([['CH', switzerland_df['unemployment_rate'].mean()]], columns=['State', '2016'])
df_difference = pd.concat([df, row])
df_difference.reset_index(drop=True, inplace=True)

# %%
topojson_path = json.load(open(geojson_path))

# Countries that were missing in the dataset are in the same color
# as the rest of the world for which we do not show any data
topojson_path['objects']['europe']['geometries'] = [
    feature for feature 
    in topojson_path['objects']['europe']['geometries'] 
    if (feature['id'] in df_difference['State'].values)]


eu_ch_difference = folium.Map([52.3, 9.7], tiles='cartodbpositron', zoom_start=3.6)
eu_ch_difference.choropleth(geo_data=topojson_path , 
             data=df_difference,
             topojson='objects.europe',
             columns=['State', '2016'],
             key_on='feature.id',
             fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.2,
             threshold_scale=define_threshold(df,'2016',classification='equal',classes=5),
             legend_name='Percentage of unemployment (%)')

eu_ch_difference.save('maps/unemployment_europe_switzerland_difference.html')
eu_ch_difference
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Link to the map preview
#
# Map can be found [here](http://ada.arassinoux.com/unemployment_europe_switzerland_difference.html)

# %% [markdown]
# ## Observations
#
# Unemployment rate in Switzerland is the lowes in Europe. It is under 3%, while most of other European countries have between 7-15%.

# %% [markdown]
# ## 2.2 - Unemployment rates : various interpretations

# %% [markdown]
# ### Compute new "unemployment" ratios
#
# As said in the explanation of this task, The Swiss Confederation defines previousy calculated and presented unemployment rates as the number of people looking for a job divided by the size of the active population (scaled by 100). This is surely a valid choice, but as we discussed one could argue for a different categorization.
#
# Another possible categorization is to calculate the unemployment rate only taking into account people who do not have a job. So excluding people who have job, but are searching for another, we get little bit different results.
#
# First of all, we used the known unemployment rate and number of all jobseekers to calculate the exact population. We used simple math for this. We get the population by diving the number of all jobseekers with unemployment rate (this is 1% of all population), and then we multiply it by 100 to get 100% or all population.
#
# After this, we calculate unemployment rate using another approach, taking into account only people who are without a job. We calculate proportion of this people over all population, and then multiply by 100 to get percentage instead of proportion.

# %%
switzerland_df['population'] = (
    switzerland_df['all_jobseekers'] / switzerland_df['unemployment_rate']) * 100

switzerland_df['unemployed_jobseekers_unemployment_rate'] = (
    switzerland_df['unemployed_jobseekers'] / switzerland_df['population'] ) * 100

switzerland_df.head()
# Out:
#   code   canton  unemployment_rate  unemployed_jobseekers  all_jobseekers  \
# 0   ZH   Zurich                3.7                 361007          441431
# 1   BE    Berne                2.7                 183398          241011
# 2   LU  Lucerne                2.1                  55221           89599
# 3   UR      Uri                1.0                   2418            4361
# 4   SZ   Schwyz                1.8                  18446           27475
#
#    employed_jobseekers    population  unemployed_jobseekers_unemployment_rate
# 0                80424  1.193057e+07                                 3.025900
# 1                57613  8.926333e+06                                 2.054573
# 2                34378  4.266619e+06                                 1.294257
# 3                 1943  4.361000e+05                                 0.554460
# 4                 9029  1.526389e+06                                 1.208473

# %% [markdown]
# ### Plot swiss maps

# %%
switzerland_map = folium.Map([46.8001, 8.1958], tiles='cartodbpositron', zoom_start=8)

switzerland_map.choropleth(geo_data=switzerland_topojson, data=switzerland_df, 
                           topojson= 'objects.cantons',
                           columns=['code', 'unemployment_rate'],
                           key_on='feature.id',
                           fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.2,
                           legend_name='Percentage of unemployment (%)')

switzerland_map.save('maps/unemployment_switzerland_all_jobseekers.html')
switzerland_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Link to the map preview
#
# Map can be found [here](http://ada.arassinoux.com/unemployment_switzerland_all_jobseekers.html)

# %%
# we will use the values from prevoius map to decide on threshold_scale
# This way both of the maps will have the same scale for colours and 
# we can use coloring to understand the difference

def define_threshold_switzerland(df, column_name , classes=4 ):
    min_val = df['unemployment_rate'].values.min()
    max_val = df['unemployment_rate'].values.max()
    bins = []
    bins.append(min_val - 0.001)
    for i in np.arange(1, classes):
        bins.append(((max_val - min_val)* i/classes) + min_val)
    bins.append(max_val + 0.001)
    return bins

# %%
switzerland_map = folium.Map([46.8001, 8.1958], tiles='cartodbpositron', zoom_start=8)

switzerland_map.choropleth(geo_data=switzerland_topojson, data=switzerland_df, topojson= 'objects.cantons',
             columns=['code', 'unemployed_jobseekers_unemployment_rate'],
             key_on='feature.id',
             fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.2,
             threshold_scale=define_threshold_switzerland(switzerland_df, '2016', classes=5),
             legend_name='Percentage of unemployment (%)')

switzerland_map.save('maps/unemployment_switzerland_unemployed_jobseekers.html')
switzerland_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Link to the map preview
#
# Map can be found [here](http://ada.arassinoux.com/unemployment_switzerland_unemployed_jobseekers.html)

# %% [markdown]
# ## Observations and discussion
#
# We notice that when we exclude the people who are unemployed but already have a job, that unemployment rate
# decreases significanlty. This means that most of the people who are calculated into unemployed actually already have a job.
#
# As map is not really good and convenient to understand these rates, we are plotting the line chart. One line chart is representing the percentage of unemployed when we take into account employed jobseekers, and another is when we take into account only employed jobseekers.
#
# Here is this difference shown even better than on the map. We see that there is significant difference in rates when we just take into account people who do not have a job.

# %%
fig, ax = plt.subplots(figsize=(15,10))
x = [i for i in np.arange(0, len(switzerland_df))]
ax.plot(x, switzerland_df.unemployment_rate)
ax.plot(x, switzerland_df.unemployed_jobseekers_unemployment_rate)
ax.set_ylabel("Percentage of unemployed")
ax.set_xlabel("Cantons")
plt.xticks(x, switzerland_df['canton'], rotation='vertical')
ax.legend(["Counting employed jobseekers", "Counting only unemployed jobseekers"])

# %% [markdown]
# # Task 3 : Swiss unemployment data with additional attributes

# %% [markdown]
# In this task we also decided to take into account the previous year 2016.

# %% [markdown]
# ## 3.1 - Nationality
# We find on amstat website a dataset that contains unemployment rates for each canton, according to the nationality of the jobseekers. We distinguished two classes:
# - Swiss people
# - Foreign people

# %%
switzerland_nationality_path = 'data/unemployment_nationality.csv'
switzerland_nationality_df = pd.read_csv(open(switzerland_nationality_path,
                                              encoding='utf-16'),
                                              header=[1,2],
                                              thousands='\'')

switzerland_nationality_df = switzerland_nationality_df[['Canton','Nationalité' ,'Total']]
cols = ['canton', 
        'nationality',
        'unemployment_rate',
        'employed_jobseekers',
        'all_jobseekers',
        'unemployed_jobseekers']

switzerland_nationality_df.columns = cols
switzerland_nationality_df.head()
# Out:
#     canton nationality  unemployment_rate  employed_jobseekers  \
# 0   Zurich   Etrangers                6.0               164436
# 1   Zurich     Suisses                2.8               196571
# 2    Berne   Etrangers                6.5                69502
# 3    Berne     Suisses                2.0               113896
# 4  Lucerne   Etrangers                4.7                22927
#
#    all_jobseekers  unemployed_jobseekers
# 0          202818                  38382
# 1          238613                  42042
# 2           93346                  23844
# 3          147665                  33769
# 4           39061                  16134

# %%
switzerland_all_nationality_df = pd.merge(cantons,switzerland_nationality_df, on=['canton'])

# Split dataframe by nationality attribute
switzerland_strangers_df = switzerland_all_nationality_df.query('nationality == \'Etrangers\'') 
switzerland_suisses_df = switzerland_all_nationality_df.query('nationality == \'Suisses\'') 

switzerland_suisses_df.reset_index(inplace=True)
switzerland_strangers_df.reset_index(inplace=True)

#Swiss people dataframe
switzerland_suisses_df.head()
# Out:
#    index code   canton nationality  unemployment_rate  employed_jobseekers  \
# 0      1   ZH   Zurich     Suisses                2.8               196571
# 1      3   BE    Berne     Suisses                2.0               113896
# 2      5   LU  Lucerne     Suisses                1.5                32294
# 3      7   UR      Uri     Suisses                0.6                 1140
# 4      9   SZ   Schwyz     Suisses                1.2                 9999
#
#    all_jobseekers  unemployed_jobseekers
# 0          238613                  42042
# 1          147665                  33769
# 2           50538                  18244
# 3            2091                    951
# 4           14425                   4426

# %%
#Foreign people dataframe
switzerland_strangers_df.head()
# Out:
#    index code   canton nationality  unemployment_rate  employed_jobseekers  \
# 0      0   ZH   Zurich   Etrangers                6.0               164436
# 1      2   BE    Berne   Etrangers                6.5                69502
# 2      4   LU  Lucerne   Etrangers                4.7                22927
# 3      6   UR      Uri   Etrangers                4.2                 1278
# 4      8   SZ   Schwyz   Etrangers                3.9                 8447
#
#    all_jobseekers  unemployed_jobseekers
# 0          202818                  38382
# 1           93346                  23844
# 2           39061                  16134
# 3            2270                    992
# 4           13050                   4603

# %% [markdown]
# ### Map of unemployment rate - difference between swiss and foreigners
#
#
#
# On the map, we show the unemployment rate for both swiss and foreigners people, using multiple layers. This enables us to see both rates. For exemple, bright colors means high unemployment rates for both swiss and foreigners.

# %%
#Layer Control add to see both maps in one
m_switzerland_swiss_foreigners = folium.Map([46.8001, 8.1958], tiles='cartodbpositron', zoom_start=8)

m_switzerland_swiss_foreigners.choropleth(geo_data=switzerland_topojson, 
             data=switzerland_suisses_df,
             columns=['code', 'unemployment_rate'],
             key_on='feature.id',
             fill_color='YlOrRd', fill_opacity=0.3, line_opacity=0.2,
             legend_name='Unemployment rate - Swiss population (%)',
             name='Unemployment rates - Swiss population',
             topojson='objects.cantons')

# scale another map to the same colors, use already introduces function
m_switzerland_swiss_foreigners.choropleth(geo_data=switzerland_topojson, 
             data=switzerland_strangers_df,
             columns=['code', 'unemployment_rate'],
             key_on='feature.id',
             fill_color='YlOrRd', fill_opacity=0.3, line_opacity=0.2,
             legend_name='Unemployment rate - Foreign population (%)', 
             name='Unemployment rates - Foreign population',
             threshold_scale = define_threshold_switzerland(switzerland_df,'2016',classes=5),
             topojson='objects.cantons')

folium.LayerControl(collapsed=False).add_to(m_switzerland_swiss_foreigners)

m_switzerland_swiss_foreigners.save('maps/unemployment_switzerland_swiss_foreigners.html')
m_switzerland_swiss_foreigners
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Link to the map preview
#
# Map can be found [here](http://ada.arassinoux.com/unemployment_switzerland_swiss_foreigners.html)

# %% [markdown]
# ### Distribution between swiss and foreigners jobseekers

# %%
# TODO: Do a bar plot to see distribution between swiss and foreigners
switzerland_nationality_diff_df = switzerland_suisses_df.copy()[['index', 'code', 'canton']]
switzerland_nationality_diff_df['total_jobseekers'] = switzerland_suisses_df['all_jobseekers'] + switzerland_strangers_df['all_jobseekers']

switzerland_nationality_diff_df['Swiss jobseekers'] = switzerland_suisses_df['all_jobseekers'] / switzerland_nationality_diff_df['total_jobseekers']
switzerland_nationality_diff_df['Foreign jobseekers'] = switzerland_strangers_df['all_jobseekers'] / switzerland_nationality_diff_df['total_jobseekers']

switzerland_nationality_diff_df = switzerland_nationality_diff_df.set_index('canton', drop=True)
switzerland_nationality_diff_df = switzerland_nationality_diff_df[['Swiss jobseekers', 'Foreign jobseekers']]

# %%
fig, ax = plt.subplots(figsize=(20,10))
switzerland_nationality_diff_df.plot.barh(stacked=True,
                                          grid=True,
                                          width=0.7,
                                          ax=ax)

plt.xlabel('Proportion of jobseekers according to nationality',fontsize=23)
plt.ylabel('Canton', fontsize=23)
plt.yticks(fontsize=20)
plt.legend(fontsize=20)

# %% [markdown]
# #### Observations
# We can see that there is no big differences between the cantons concerning the proportion of jobseekers according nationality. We can see that Jura canton has the biggest proportion of swiss jobseekers while Grisons, Bâle-Ville and Glaris have the biggest proportion of foreign jobseekers.

# %% [markdown]
# ## 3.2 - Nationality and age groups
#
# Now let's refine the analysis by adding the differences between age groups. As you may have guessed it is nearly impossible to plot so many variables on a map. Make a bar plot, which is a better suited visualization tool for this type of multivariate data.

# %% [markdown]
# ### Assumptions
# We don't achieve to get unemployment rates for all classes (age and nationality).<br>
# As a matter of fact, we decided to show the distribution between all the subclasses using one final horizontal barplot.

# %%
def define_age_classes(x):
    if(x == '1'):
        return ' 15 - 24 years'
    elif(x == '2'):
        return ' 25 - 49 years'
    else:
        return ' 50+ years'

# %%
switzerland_age_groups_path = 'data/unemployment_nationality_age.csv'

#Some preprocessing 
switzerland_age_df = pd.read_csv(open(switzerland_age_groups_path,
                                      encoding='utf-16'),
                                      header=[1,2],
                                      thousands='\'')

#Remove total rows as we don't need it
switzerland_age_df = switzerland_age_df[~switzerland_age_df.isin(['Total'])]
switzerland_age_df = switzerland_age_df.drop(['Mesures', 'Unnamed: 3_level_1'],
                                             axis=1, level=1) .dropna()
                                           
switzerland_age_df.rename(
                columns={'Classes d\'âge 15-24, 25-49, 50 ans et plus': 'classes'},
                inplace=True)


switzerland_age_df.columns = switzerland_age_df.columns.droplevel(1)
switzerland_age_df['Total'] = np.round(switzerland_age_df.mean(axis=1).astype('int64'))
switzerland_age_df['classes'] = switzerland_age_df['classes'].apply(
                                lambda x: define_age_classes(x))

switzerland_age_df['Nationality + age'] = switzerland_age_df['Nationalité'] + ' ' + switzerland_age_df['classes']

# Use pivot function for horizontal bar plot
switzerland_age_df = switzerland_age_df.pivot(index='Canton',
                                              columns='Nationality + age',
                                              values='Total')


switzerland_age_df['total'] = [0 for i in range(len(switzerland_age_df))]

for p in switzerland_age_df.columns[0:len(switzerland_age_df.columns)-1]:
    switzerland_age_df['total'] += switzerland_age_df[p]
    
for p in switzerland_age_df.columns[0:len(switzerland_age_df.columns)-1]:
    switzerland_age_df[p] = switzerland_age_df[p]/switzerland_age_df['total']
    
switzerland_age_df.drop('total', axis=1, inplace=True)

switzerland_age_df.head()
# Out:
# Nationality + age             Etrangers  15 - 24 years  \
# Canton
# Appenzell Rhodes-Extérieures                  0.030526
# Appenzell Rhodes-Intérieures                  0.050360
# Argovie                                       0.049900
# Berne                                         0.033811
# Bâle-Campagne                                 0.033123
#
# Nationality + age             Etrangers  25 - 49 years  Etrangers  50+ years  \
# Canton
# Appenzell Rhodes-Extérieures                  0.243158              0.100000
# Appenzell Rhodes-Intérieures                  0.251799              0.129496
# Argovie                                       0.332832              0.101741
# Berne                                         0.271636              0.081864
# Bâle-Campagne                                 0.294861              0.092710
#
# Nationality + age             Suisses  15 - 24 years  Suisses  25 - 49 years  \
# Canton
# ...

# %% [markdown]
# ### Analysis on the distribution

# %%
fig, ax = plt.subplots(figsize=(14,8))
switzerland_age_df.plot.barh(stacked=True, grid=True, width=0.7, ax=ax)
plt.xlabel('Proportion of registered unemployed people',fontsize=30)
plt.ylabel('Canton', fontsize=30)
plt.yticks(fontsize=20)
plt.legend(fontsize=20, shadow=True)
plt.show()

# %%
# TODO: we can also use box plots to show the distribution of the values among each columns
switzerland_age_df.plot.box(figsize=(16,8))

# %% [markdown]
# ### Observations
# So here we see that the age category from 25 to 49 years is the most touched by unemployment, regardless of nationality. Regardless of nationality, we also see that the age category for 15 to 24 years is the least touched by unemployment.
#
# Looking at the boxes, we see that the difference between swiss and foreign unemployed is bigger when we look at age category from 50+ years, where foreign people are way less touched by unemployment.
#
# It is also interesting to see that for 2 categories (15 - 24 years and 50+ years), foreign people are less unemployed than swiss people, but when we compute unemployment for swiss and foreign people in task 2, foreign people were more unemployed than swiss people. So we can suppose that there is more foreign people from age category from 25 to 49 years than from the 2 others categories, so they take the unemployment rate up (as they are the most unemployed category).

# %% [markdown]
# # Bonus part : Röstigraben
#
# Using the map you have just built, and the geographical information contained in it, could you give a rough estimate of the difference in unemployment rates between the areas divided by the Röstigraben?

# %% [markdown]
# ## Methodology

# %% [markdown]
# In order to see nicely the three Rostigraben regions on the map, we plot cantons with different bording colors, according if people speak French (FR), German (DE) or Italian (IT).

# %%
def rostigraben_colors(feature_id):
    IT = ['TI']
    FR = ['GE', 'VD', 'FR', 'NE', 'VS', 'JU']
    
    if feature_id in IT:
            return '#4daf4a';
    elif feature_id in FR:
        return '#377eb8'
    else:
        return '#e41a1c'

# %%
rostigraben_map = folium.Map([46.8001, 8.1958], tiles='cartodbpositron', zoom_start=8)

# Layer 1: unemployment rate
rostigraben_map.choropleth(geo_data=switzerland_topojson, data=switzerland_df,
             columns=['code', 'unemployment_rate'],
             key_on='feature.id',
             fill_color='YlOrRd', fill_opacity=0.3, line_opacity=0,
             legend_name='Unemployment rate - Swiss population (%)',
             name='Unemployment rates - Swiss population',
             topojson='objects.cantons',
             threshold_scale=define_threshold(switzerland_suisses_df,'unemployment_rate', 'equal',5))

# Layer 2: cantons borders according to rostigraben regions
folium.TopoJson(
    switzerland_topojson,
    name = 'Languages spoken according to Rostigraben',
    object_path ='objects.cantons',
    style_function=lambda feature: {
        'fill_color': 'white',
        'fillOpacity': 0,
        'weight' : 3,
        'color': rostigraben_colors(feature['id']),
        'opacity': 1  
    }
).add_to(rostigraben_map)

folium.LayerControl(collapsed=False).add_to(rostigraben_map)
rostigraben_map.save('maps/unemployment_switzerland_rostigraben.html')
rostigraben_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Link to the map preview
#
# Map can be found [here](http://ada.arassinoux.com/unemployment_switzerland_rostigraben.html)

# %% [markdown]
# ### 2 - Statistics data

# %%
# TODO : nice array or graph to show mean and variance of unemployement rates between rostigraben regions
switzerland_suisses_df.head()
switzerland_strangers_df.head()

def define_speaking_area(val):
    IT = ['TI']
    FR = ['GE', 'VD', 'FR', 'NE', 'VS', 'JU']
    
    if (val in IT):
        return 'IT'
    if (val in FR):
        return 'FR'
    else:
        return 'DE'

switzerland_df['language']= switzerland_df['code'].apply(define_speaking_area).copy()

fig, ax = plt.subplots(figsize=(9,8))
plt.title("Unemployment rate by Rostigraben regions")
ax = sns.barplot(x="language", y="unemployment_rate", data=switzerland_df)

# %% [markdown]
# ### Observations

# %% [markdown]
# We notice that the highest unemployment rate is for the french spoken area. The lowest is for the german spoken area.
