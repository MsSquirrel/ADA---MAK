# %% [markdown]
# # Homework 3 - Data viz

# %% [markdown]
# ###TODO

# %%
import os
import pandas as pd
import json
import folium

# %% [markdown]
# import folium

# %%
folium.__version__ == '0.5.0'
# Out:
# True

# %% [markdown]
# Short Description:
#
# (Using Table tec00112 that presents data on employment, based on the domestic concept.)
# Employment covers all persons engaged in some productive activity that falls within the production boundary
# of the national accounts. Employed persons are either employees (persons who work by agreement, work for a
# resident institutional unit and receive a remuneration recorded as compensation of employees) or self-employed
# (persons who are the sole owners, or joint owners, of the unincorporated enterprises in which they work, excluding
#  those unincorporated enterprises that are classified as quasi-corporations).The domestic concept of employment
# includes both the residents and the non-residents who work for resident producer units.

# %%
FILE_PATH = "data/"

# %%
df = pd.DataFrame()
df = df.append( pd.read_csv("data/tec00112.tsv", sep="\t" , header=0))
df.columns = [i.split(" ")[0] for i in df.columns]
df.columns = [i.split("\\")[0] for i in df.columns]
p = df['unit,nace_r2,na_item,geo'].str.split(",")
df['unit,nace_r2,na_item,geo'] = [pi[3] for pi in p]
df
# Out:
#    unit,nace_r2,na_item,geo        2005        2006        2007        2008  \
# 0                        AT    3872.90     3940.73     4012.73     4089.13
# 1                        BE    4255.30     4302.90     4374.00     4453.00
# 2                        BG    3495.27     3612.04     3726.74     3814.65
# 3                        CH    4144.66     4234.93     4344.27     4448.26
# 4                        CY     366.46      373.25      389.77      403.51
# 5                        CZ    4922.64     4988.98     5093.14     5204.08
# 6                        DE   39326.00    39635.00    40325.00    40856.00
# 7                        DK    2783.00     2846.00     2912.00     2947.00
# 8                        EA  140820.92   143274.00   146917.17   148694.59
# 9                      EA18  145938.49   148544.43   151348.33   152638.90
# 10                     EA19  147359.20   149960.69   152793.47   154064.99
# 11                       EE     612.30      642.20      643.40      642.10
# 12                       EL    4646.87     4731.34     4795.07     4856.36
# 13                       ES   19784.00    20609.20    21284.90    21324.10
# 14                     EU28  220897.89   224686.64   228889.84   231215.63
# 15                       FI    2410.60     2454.60     2506.90     2562.70
# 16                       FR   26374.00    26664.00    27039.00    27166.00
# 17                       HR   1637.54 p   1689.26 p   1742.67 p   1779.87 d
# 18                       HU    4174.19     4192.22     4197.97     4115.47
# 19                       IE    1962.30     2053.00     2142.74     2129.25
# 20                       IT   24501.30    24983.80    25294.90    25349.20
# 21                       LI          :           :           :           :
# 22                       LT    1420.72     1416.26     1445.14     1426.09
# 23                       LU     307.69      319.48      333.55      349.46
# 24                       LV     969.15     1024.95     1064.07     1055.07
# 25                       MK     587.48      614.58      632.90      682.96
# 26                       MT     151.26      153.51      156.95      160.94
# 27                       NL    8339.00     8519.00     8771.00     8914.00
# 28                       NO    2354.00     2434.00     2535.00     2617.00
# 29                       PL   14057.00    14503.90    15155.90    15731.90
# 30                       PT    5040.96     5060.86     5061.58     5080.13
# 31                       RO    9267.20     9330.70     9364.80     9365.90
# 32                       SE    4348.70     4422.40     4524.40     4565.20
# 10  151373.14   153393.23
# 11     622.90      624.70
# 12   4064.04 p   4083.03 p
# 13  18521.30 p  18987.40 p
# 14  229324.65   232135.67
# 15    2504.10     2516.60
# 16  27434.00 p  27612.00 p
# 17   1594.59 d   1599.19 d
# 18    4315.55     4429.45
# 19    1989.41     2045.45
# 20   24497.90    24809.40
# 21      36.76           :
# 22    1334.73     1361.21
# 23     406.11      418.44
# 24     889.00      886.30
# 25          :           :
# 26     195.93      203.15
# 27   8806.00 p   8901.00 p
# 28    2757.00     2764.00
# 29   15970.00   16060.70 p
# 30    4575.82    4650.51 p
# 31    8525.70    8449.00 p
# 32    4807.40     4889.80
# 33     941.56      959.74
# 34    2267.10     2321.05
# 35   31281.15    31725.39

# %%
STUPID_NAME = '2016'
STUPID_NAME_2 = 'unit,nace_r2,na_item,geo'
reg_ex = "p|d|:"

def clean_unemployed_column(df, column_name):
    for i in range(df[column_name].shape[0]):
        df[column_name][i] =  df[column_name][i].split("p")[0]
        df[column_name][i] =  df[column_name][i].split("d")[0]
        df[column_name][i] =  df[column_name][i].split(":")[0]
    
clean_unemployed_column(df, STUPID_NAME)
clean_unemployed_column(df, STUPID_NAME_2)

df[STUPID_NAME].fillna(0, inplace = True)
df
# Out:
#    unit,nace_r2,na_item,geo        2005        2006        2007        2008  \
# 0                        AT    3872.90     3940.73     4012.73     4089.13
# 1                        BE    4255.30     4302.90     4374.00     4453.00
# 2                        BG    3495.27     3612.04     3726.74     3814.65
# 3                        CH    4144.66     4234.93     4344.27     4448.26
# 4                        CY     366.46      373.25      389.77      403.51
# 5                        CZ    4922.64     4988.98     5093.14     5204.08
# 6                        DE   39326.00    39635.00    40325.00    40856.00
# 7                        DK    2783.00     2846.00     2912.00     2947.00
# 8                        EA  140820.92   143274.00   146917.17   148694.59
# 9                      EA18  145938.49   148544.43   151348.33   152638.90
# 10                     EA19  147359.20   149960.69   152793.47   154064.99
# 11                       EE     612.30      642.20      643.40      642.10
# 12                       EL    4646.87     4731.34     4795.07     4856.36
# 13                       ES   19784.00    20609.20    21284.90    21324.10
# 14                     EU28  220897.89   224686.64   228889.84   231215.63
# 15                       FI    2410.60     2454.60     2506.90     2562.70
# 16                       FR   26374.00    26664.00    27039.00    27166.00
# 17                       HR   1637.54 p   1689.26 p   1742.67 p   1779.87 d
# 18                       HU    4174.19     4192.22     4197.97     4115.47
# 19                       IE    1962.30     2053.00     2142.74     2129.25
# 20                       IT   24501.30    24983.80    25294.90    25349.20
# 21                       LI          :           :           :           :
# 22                       LT    1420.72     1416.26     1445.14     1426.09
# 23                       LU     307.69      319.48      333.55      349.46
# 24                       LV     969.15     1024.95     1064.07     1055.07
# 25                       MK     587.48      614.58      632.90      682.96
# 26                       MT     151.26      153.51      156.95      160.94
# 27                       NL    8339.00     8519.00     8771.00     8914.00
# 28                       NO    2354.00     2434.00     2535.00     2617.00
# 3     4899.75     4969.93     CH
# 4      368.37      379.93     CY
# 5     5181.91     5248.55     CZ
# 6    43069.00    43638.00     DE
# 7     2829.00     2877.00     DK
# 8   151373.14   153393.23     EA
# 9   150038.41   152032.02   EA18
# 10  151373.14   153393.23   EA19
# 11     622.90      624.70     EE
# 12   4064.04 p    4083.03     EL
# 13  18521.30 p   18987.40     ES
# 14  229324.65   232135.67   EU28
# 15    2504.10     2516.60     FI
# 16  27434.00 p   27612.00     FR
# 17   1594.59 d    1599.19     HR
# 18    4315.55     4429.45     HU
# 19    1989.41     2045.45     IE
# 20   24497.90    24809.40     IT
# 21      36.76                 LI
# 22    1334.73     1361.21     LT
# 23     406.11      418.44     LU
# 24     889.00      886.30     LV
# 25          :                 MK
# 26     195.93      203.15     MT
# 27   8806.00 p    8901.00     NL
# 28    2757.00     2764.00     NO
# 29   15970.00    16060.70     PL
# 30    4575.82     4650.51     PT
# 31    8525.70     8449.00     RO
# 32    4807.40     4889.80     SE
# 33     941.56      959.74     SI
# 34    2267.10     2321.05     SK
# 35   31281.15    31725.39     UK

# %%
df["State"] = df["unit,nace_r2,na_item,geo"]


#state_geo_path = r'topojson/europe.topojson.json'
state_geo_path = r'geojson/europe.topojson'

topojson_path = os.path.join('topojson', 'europe.topojson.json')

df['test_2016'] = [i*1000 for i in range(df.shape[0])]

eu_map = folium.Map([45, 20], tiles='cartodbpositron', zoom_start=3.6)

# topojson='' try this!
eu_map.choropleth(geo_data=geo_json_data, data=df,
             columns=['State', 'test_2016'],
             key_on='feature.id',
             fill_color='BuPu', fill_opacity=0.7, line_opacity=0.2,
             legend_name='Percentage for winner of general election (%)')


folium.TopoJson(
    open(topojson_path),
    'objects.europe'
    name='topojson'
).add_to(eu_map)

folium.LayerControl().add_to(eu_map)

eu_map
# Out:
#   File "<ipython-input-60-4259230cf012>", line 14
#     columns=['State', 'test_2016'],
#           ^
# SyntaxError: invalid syntax

# %%
m = folium.Map(location=[48, -102], zoom_start=3)

m.choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=df,
    columns=['State', '2016'],
    key_on='feature.id',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Unemployment Rate (%)'
)


folium.LayerControl().add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-925b3a01ea49> in <module>()
#      11     fill_opacity=0.7,
#      12     line_opacity=0.2,
# ---> 13     legend_name='Unemployment Rate (%)'
#      14 )
#      15
#
# /home/kristina/anaconda3/lib/python3.6/site-packages/folium/folium.py in choropleth(self, geo_data, data, columns, key_on, threshold_scale, fill_color, fill_opacity, line_color, line_weight, line_opacity, name, legend_name, topojson, reset, smooth_factor, highlight)
#     271                 data_max = (data_max if data_max > 0 else 0
#     272                             if data_max < 0 else 1)
# --> 273             data_min, data_max = (1.01*data_min-0.01*data_max,
#     274                                   1.01*data_max-0.01*data_min)
#     275             nb_class = 6
#
# TypeError: can't multiply sequence by non-int of type 'float'
